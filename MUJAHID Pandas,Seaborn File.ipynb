# %%
import pandas as pd

# %%
df = pd.read_csv('Ahmed1.csv')

# %%
df
# Out:
#     Sno      Column1  Column3  Column4  Column5  Column6
# 0     1    23.000000       45      NaN      NaN      NaN
# 1     2    34.000000       45      NaN      NaN      NaN
# 2     3   443.000000       45      5.0      NaN      NaN
# 3     1   586.666667       45      NaN      NaN      NaN
# 4     1   796.666667       45      NaN      NaN      NaN
# 5     1  1006.666667       45      NaN      NaN      NaN
# 6     1  1216.666667       45      NaN      NaN      NaN
# 7     1  1426.666667       45      NaN      NaN      NaN
# 8     1  1636.666667       45      NaN      NaN      NaN
# 9     1  1846.666667       45      NaN      NaN      NaN
# 10    1  2056.666667       45      NaN      NaN      NaN
# 11    1  2266.666667       45      NaN      NaN      NaN
# 12    1  2476.666667       45      NaN      NaN      NaN
# 13    1  2686.666667       45      NaN      NaN      NaN

# %%
df['Sno'].value_counts()
# Out:
# 1    12
# 2     1
# 3     1
# Name: Sno, dtype: int64

# %%
len(df)
# Out:
# 14

# %%
df.shape
# Out:
# (14, 6)

# %%
df['Sno'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#              Sno      Column1  Column3  Column4  Column5  Column6
# count  14.000000    14.000000     14.0      1.0      0.0      0.0
# mean    1.214286  1321.666667     45.0      5.0      NaN      NaN
# std     0.578934   879.648123      0.0      NaN      NaN      NaN
# min     1.000000    23.000000     45.0      5.0      NaN      NaN
# 25%     1.000000   639.166667     45.0      5.0      NaN      NaN
# 50%     1.000000  1321.666667     45.0      5.0      NaN      NaN
# 75%     1.000000  2004.166667     45.0      5.0      NaN      NaN
# max     3.000000  2686.666667     45.0      5.0      NaN      NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Sno, Column1, Column3, Column4, Column5, Column6]
# Index: []

# %%
df.fillna(12)
# Out:
#     Sno      Column1  Column3  Column4  Column5  Column6
# 0     1    23.000000       45     12.0     12.0     12.0
# 1     2    34.000000       45     12.0     12.0     12.0
# 2     3   443.000000       45      5.0     12.0     12.0
# 3     1   586.666667       45     12.0     12.0     12.0
# 4     1   796.666667       45     12.0     12.0     12.0
# 5     1  1006.666667       45     12.0     12.0     12.0
# 6     1  1216.666667       45     12.0     12.0     12.0
# 7     1  1426.666667       45     12.0     12.0     12.0
# 8     1  1636.666667       45     12.0     12.0     12.0
# 9     1  1846.666667       45     12.0     12.0     12.0
# 10    1  2056.666667       45     12.0     12.0     12.0
# 11    1  2266.666667       45     12.0     12.0     12.0
# 12    1  2476.666667       45     12.0     12.0     12.0
# 13    1  2686.666667       45     12.0     12.0     12.0

# %%
a=pd.read_csv('boat.csv')

# %%
a
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
a.assign(Area=lambda a: a.alone*a.alive)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone Area
# ...

# %%
a['Volume']=a.sibsp*a.age*a.age

# %%
a['Volume']
# Out:
# 0       484.0
# 1      1444.0
# 2         0.0
# 3      1225.0
# 4         0.0
#         ...
# 886       0.0
# 887       0.0
# 888       NaN
# 889       0.0
# 890       0.0
# Name: Volume, Length: 891, dtype: float64

# %%
pd.qcut(a.fare, 'n', labels=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_7004/1312079225.py in <module>
# ----> 1 pd.qcut(a.fare, '1', labels=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     369     else:
#     370         quantiles = q
# --> 371     bins = algos.quantile(x, quantiles)
#     372     fac, bins = _bins_to_cuts(
#     373         x,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in quantile(x, q, interpolation_method)
#    1190
#    1191     if is_scalar(q):
# -> 1192         return _get_score(q)
#    1193     else:
#    1194         q = np.asarray(q, np.float64)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in _get_score(at)
#    1172
#    1173         idx = at * (len(values) - 1)
# ...

# %%
a.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
# ...

# %%
a.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
# ...

# %%
a.clip(lower=-10,upper=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_7004/1943944236.py in <module>
# ----> 1 a.clip(lower=-10,upper=10)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in clip(self, lower, upper, axis, inplace, *args, **kwargs)
#   10696         **kwargs,
#   10697     ) -> DataFrame | None:
# > 10698         return super().clip(lower, upper, axis, inplace, *args, **kwargs)
#   10699
#   10700     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#
# ...

# %%
a.abs
# Out:
# <bound method NDFrame.abs of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  Volume
# ...

# %%
a.size
# Out:
# 15147

# %%
a.groupby(["age","sex"]).mean()
# Out:
#               Unnamed: 0  survived  pclass  sibsp  parch      fare  \
# age   sex
# 0.42  male         803.0       1.0     3.0    0.0    1.0    8.5167
# 0.67  male         755.0       1.0     2.0    1.0    1.0   14.5000
# 0.75  female       556.5       1.0     3.0    2.0    1.0   19.2583
# 0.83  male         454.5       1.0     2.0    0.5    1.5   23.8750
# 0.92  male         305.0       1.0     1.0    1.0    2.0  151.5500
# ...                  ...       ...     ...    ...    ...       ...
# 70.00 male         708.5       0.0     1.5    0.5    0.5   40.7500
# 70.50 male         116.0       0.0     3.0    0.0    0.0    7.7500
# 71.00 male         294.5       0.0     1.0    0.0    0.0   42.0792
# 74.00 male         851.0       0.0     3.0    0.0    0.0    7.7750
# 80.00 male         630.0       1.0     1.0    0.0    0.0   30.0000
#
#               adult_male  alone      Volume
# age   sex
# 0.42  male           0.0    0.0     0.00000
# 0.67  male           0.0    0.0     0.44890
# ...

# %%
a.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
# ...

# %%
a.rolling
# Out:
# <bound method NDFrame.rolling of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  Volume
# ...

# %%
a.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a.plot.scatter(x='age',y='pclass')
# Out:
# <AxesSubplot:xlabel='age', ylabel='pclass'>

# %%
a.shift(1)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0           NaN       NaN     NaN     NaN   NaN    NaN    NaN      NaN
# 1           0.0       0.0     3.0    male  22.0    1.0    0.0   7.2500
# 2           1.0       1.0     1.0  female  38.0    1.0    0.0  71.2833
# 3           2.0       1.0     3.0  female  26.0    0.0    0.0   7.9250
# 4           3.0       1.0     1.0  female  35.0    1.0    0.0  53.1000
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886       885.0       0.0     3.0  female  39.0    0.0    5.0  29.1250
# 887       886.0       0.0     2.0    male  27.0    0.0    0.0  13.0000
# 888       887.0       1.0     1.0  female  19.0    0.0    0.0  30.0000
# 889       888.0       0.0     3.0  female   NaN    1.0    2.0  23.4500
# 890       889.0       1.0     1.0    male  26.0    0.0    0.0  30.0000
#
#     embarked   class    who adult_male deck  embark_town alive  alone  Volume
# ...

# %%
a.rank(method='dense')
# Out:
#      Unnamed: 0  survived  pclass  sex   age  sibsp  parch   fare  embarked  \
# 0           1.0       1.0     3.0  2.0  29.0    2.0    1.0   19.0       3.0
# 1           2.0       2.0     1.0  1.0  52.0    2.0    1.0  208.0       1.0
# 2           3.0       2.0     3.0  1.0  35.0    1.0    1.0   42.0       3.0
# 3           4.0       2.0     1.0  1.0  48.0    2.0    1.0  190.0       3.0
# 4           5.0       1.0     3.0  2.0  48.0    1.0    1.0   44.0       3.0
# ..          ...       ...     ...  ...   ...    ...    ...    ...       ...
# 886       887.0       1.0     2.0  2.0  36.0    1.0    1.0   86.0       3.0
# 887       888.0       2.0     1.0  1.0  25.0    1.0    1.0  154.0       3.0
# 888       889.0       1.0     3.0  1.0   NaN    2.0    3.0  132.0       3.0
# 889       890.0       2.0     1.0  2.0  35.0    1.0    1.0  154.0       1.0
# 890       891.0       1.0     3.0  2.0  43.0    1.0    1.0   31.0       2.0
#
# ...

# %%
a.rank(method='min')
# Out:
#      Unnamed: 0  survived  pclass    sex    age  sibsp  parch   fare  \
# 0           1.0       1.0   401.0  315.0  205.0  609.0    1.0   71.0
# 1           2.0     550.0     1.0    1.0  527.0  609.0    1.0  789.0
# 2           3.0     550.0   401.0    1.0  302.0    1.0    1.0  224.0
# 3           4.0     550.0     1.0    1.0  480.0  609.0    1.0  746.0
# 4           5.0       1.0   401.0  315.0  480.0    1.0    1.0  243.0
# ..          ...       ...     ...    ...    ...    ...    ...    ...
# 886       887.0       1.0   217.0  315.0  320.0    1.0    1.0  387.0
# 887       888.0     550.0     1.0    1.0  140.0    1.0    1.0  652.0
# 888       889.0       1.0   401.0    1.0    NaN  609.0  797.0  546.0
# 889       890.0     550.0     1.0  315.0  302.0    1.0    1.0  652.0
# 890       891.0       1.0   401.0  315.0  429.0    1.0    1.0  107.0
#
#      embarked  class    who  adult_male  deck  embark_town  alive  alone  \
# ...

# %%
a.rank(pct=True)
# Out:
#      Unnamed: 0  survived    pclass       sex       age     sibsp     parch  \
# 0      0.001122  0.308642  0.725028  0.676768  0.305322  0.800224  0.381033
# 1      0.002245  0.808642  0.121773  0.176768  0.745098  0.800224  0.381033
# 2      0.003367  0.808642  0.725028  0.176768  0.434874  0.341751  0.381033
# 3      0.004489  0.808642  0.121773  0.176768  0.684174  0.800224  0.381033
# 4      0.005612  0.308642  0.725028  0.676768  0.684174  0.341751  0.381033
# ..          ...       ...       ...       ...       ...       ...       ...
# 886    0.995511  0.308642  0.346240  0.676768  0.460084  0.341751  0.381033
# 887    0.996633  0.808642  0.121773  0.176768  0.212885  0.341751  0.381033
# 888    0.997755  0.308642  0.725028  0.176768       NaN  0.800224  0.938833
# 889    0.998878  0.808642  0.121773  0.676768  0.434874  0.341751  0.381033
# 890    1.000000  0.308642  0.725028  0.676768  0.612745  0.341751  0.381033
#
# ...

# %%
pd.merge(a,a,how='left',on='sex')
# Out:
#         Unnamed: 0_x  survived_x  pclass_x   sex  age_x  sibsp_x  parch_x  \
# 0                  0           0         3  male   22.0        1        0
# 1                  0           0         3  male   22.0        1        0
# 2                  0           0         3  male   22.0        1        0
# 3                  0           0         3  male   22.0        1        0
# 4                  0           0         3  male   22.0        1        0
# ...              ...         ...       ...   ...    ...      ...      ...
# 431520           890           0         3  male   32.0        0        0
# 431521           890           0         3  male   32.0        0        0
# 431522           890           0         3  male   32.0        0        0
# 431523           890           0         3  male   32.0        0        0
# 431524           890           0         3  male   32.0        0        0
#
#         fare_x embarked_x class_x  ...   fare_y  embarked_y class_y  who_y  \
# ...

# %%
pd.merge(a,a,how='right',on='age')
# Out:
#        Unnamed: 0_x  survived_x  pclass_x   sex_x   age  sibsp_x  parch_x  \
# 0                 0           0         3    male  22.0        1        0
# 1                60           0         3    male  22.0        0        0
# 2                80           0         3    male  22.0        0        0
# 3               112           0         3    male  22.0        0        0
# 4               141           1         3  female  22.0        0        0
# ...             ...         ...       ...     ...   ...      ...      ...
# 42516           657           0         3  female  32.0        1        1
# 42517           665           0         2    male  32.0        2        0
# 42518           769           0         3    male  32.0        0        0
# 42519           838           1         3    male  32.0        0        0
# 42520           890           0         3    male  32.0        0        0
#
#         fare_x embarked_x class_x  ... fare_y  embarked_y class_y who_y  \
# ...

# %%
pd.merge(a,a,how='inner',on='age')
# Out:
#        Unnamed: 0_x  survived_x  pclass_x sex_x    age  sibsp_x  parch_x  \
# 0                 0           0         3  male  22.00        1        0
# 1                 0           0         3  male  22.00        1        0
# 2                 0           0         3  male  22.00        1        0
# 3                 0           0         3  male  22.00        1        0
# 4                 0           0         3  male  22.00        1        0
# ...             ...         ...       ...   ...    ...      ...      ...
# 42516           814           0         3  male  30.50        0        0
# 42517           814           0         3  male  30.50        0        0
# 42518           803           1         3  male   0.42        0        1
# 42519           843           0         3  male  34.50        0        0
# 42520           851           0         3  male  74.00        0        0
#
#        fare_x embarked_x class_x  ...  fare_y  embarked_y class_y  who_y  \
# ...

# %%
pd.merge(a,a,how='outer',on='pclass')
# Out:
#         Unnamed: 0_x  survived_x  pclass sex_x  age_x  sibsp_x  parch_x  \
# 0                  0           0       3  male   22.0        1        0
# 1                  0           0       3  male   22.0        1        0
# 2                  0           0       3  male   22.0        1        0
# 3                  0           0       3  male   22.0        1        0
# 4                  0           0       3  male   22.0        1        0
# ...              ...         ...     ...   ...    ...      ...      ...
# 321588           886           0       2  male   27.0        0        0
# 321589           886           0       2  male   27.0        0        0
# 321590           886           0       2  male   27.0        0        0
# 321591           886           0       2  male   27.0        0        0
# 321592           886           0       2  male   27.0        0        0
#
#         fare_x embarked_x class_x  ...   fare_y  embarked_y class_y  who_y  \
# ...

# %%
pd.merge('pclass','age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_7004/1591190544.py in <module>
# ----> 1 pd.merge('pclass','age')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625         validate: str | None = None,
#     626     ):
# --> 627         _left = _validate_operand(left)
#     628         _right = _validate_operand(right)
# ...
