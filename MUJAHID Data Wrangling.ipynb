# %%
import pandas as pd

# %%
Dataset=pd.read_csv('Ahmed.csv')

# %%
Dataset
# Out:
#    Sno  Column1  Column3  Column4  Column5  Column6
# 0    1       23     45.0      NaN      NaN      NaN
# 1    2       34     45.0      NaN      NaN      NaN
# 2    3      443      NaN      5.0      NaN      NaN

# %%
import pandas as pd

# %%
df = pd.read_csv('Ahmed1.csv')

# %%
df
# Out:
#     Sno      Column1  Column3  Column4  Column5  Column6
# 0     1    23.000000       45      NaN      NaN      NaN
# 1     2    34.000000       45      NaN      NaN      NaN
# 2     3   443.000000       45      5.0      NaN      NaN
# 3     1   586.666667       45      NaN      NaN      NaN
# 4     1   796.666667       45      NaN      NaN      NaN
# 5     1  1006.666667       45      NaN      NaN      NaN
# 6     1  1216.666667       45      NaN      NaN      NaN
# 7     1  1426.666667       45      NaN      NaN      NaN
# 8     1  1636.666667       45      NaN      NaN      NaN
# 9     1  1846.666667       45      NaN      NaN      NaN
# 10    1  2056.666667       45      NaN      NaN      NaN
# 11    1  2266.666667       45      NaN      NaN      NaN
# 12    1  2476.666667       45      NaN      NaN      NaN
# 13    1  2686.666667       45      NaN      NaN      NaN

# %%
a=pd.DataFrame({'a':[4,5,6,7,8,9,1,23,3],'b':[7,8,9,3,4,56,6,7,8],'c':[10,11,12,1,2,3,4,5,6]},index=[1,2,3,4,5,6,7,8,9])

# %%
a
# Out:
#     a   b   c
# 1   4   7  10
# 2   5   8  11
# 3   6   9  12
# 4   7   3   1
# 5   8   4   2
# 6   9  56   3
# 7   1   6   4
# 8  23   7   5
# 9   3   8   6

# %%
b=pd.DataFrame([[4,5,6],[7,8,9],[10,11,12]],index=[1,2,3],columns=['a','b','c'])

# %%
b
# Out:
#     a   b   c
# 1   4   5   6
# 2   7   8   9
# 3  10  11  12

# %%
df.describe()
# Out:
#          a    b     c
# count  3.0  3.0   3.0
# mean   5.0  8.0  11.0
# std    1.0  1.0   1.0
# min    4.0  7.0  10.0
# 25%    4.5  7.5  10.5
# 50%    5.0  8.0  11.0
# 75%    5.5  8.5  11.5
# max    6.0  9.0  12.0

# %%
df.max()
# Out:
# a     6
# b     9
# c    12
# dtype: int64

# %%
df.iloc[1:2,1:3]
# Out:
#    b   c
# 2  8  11

# %%
df.drop(['a'],axis=1)
# Out:
#    b   c
# 1  7  10
# 2  8  11
# 3  9  12

# %%
df.mean()
# Out:
# a     5.0
# b     8.0
# c    11.0
# dtype: float64

# %%
df.groupby(['a','b']).mean()
# Out:
#         c
# a b
# 4 7  10.0
# 5 8  11.0
# 6 9  12.0

# %%
w=pd.DataFrame({'a':[4,5,6],'b':[7,8,9],'c':[10,11,12]},index=pd.MultiIndex.from_tuples([('d',1),('d',2),('e',2)],
                                                                                        names=['n','v']))

# %%
w
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
q=(pd.melt(df).rename(columns={'variable':'var','value':'val'}).query('val>=200'))

# %%
q
# Out:
# Empty DataFrame
# Columns: [var, val]
# Index: []

# %%
pd.melt(df)
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12

# %%
pd.concat([a,b])
# Out:
#     a   b   c
# 1   4   7  10
# 2   5   8  11
# 3   6   9  12
# 4   7   3   1
# 5   8   4   2
# 6   9  56   3
# 7   1   6   4
# 8  23   7   5
# 9   3   8   6
# 1   4   5   6
# 2   7   8   9
# 3  10  11  12

# %%
df.pivot(columns='a',values='8')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_8200/2763853065.py in <module>
# ----> 1 df.pivot(columns='a',values='8')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     499     else:
#     500         if index is None:
# --> 501             index_list = [Series(data.index, name=data.index.name)]
#     502         else:
#     503             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#
# ...

# %%
df.sort_values('a')
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
